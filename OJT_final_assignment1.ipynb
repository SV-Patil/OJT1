# %% [markdown]
# ### Q1. Data visualization and statistical measures.
# for this question you are required to analyse the iris dataset using python. Perform all data visualization techniques on all numerical columns of the dataset. addtionally calculate all possible statistical measures for each numerical columns.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stat
import matplotlib.pyplot as plt
import statistics

# %%
dataset = pd.read_csv("Data/iris.csv")
dataset
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
PL = dataset["Petal.Length"]
SL = dataset["Sepal.Length"]
PW = dataset["Petal.Width"]
SW = dataset["Sepal.Width"]

# %%
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.hist(SL)
plt.xlabel("Sepal Length")

plt.subplot(2,2,2)
plt.hist(SW)
plt.xlabel("Sepal Width")

plt.subplot(2,2,3)
plt.hist(PL)
plt.xlabel("Petal Length")

plt.subplot(2,2,4)
plt.hist(PW)
plt.xlabel("Petal Width")

plt.show()

# %%
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.scatter(PL,SL)

plt.subplot(2,2,2)
plt.scatter(PL,SW)

plt.subplot(2,2,3)
plt.scatter(PW,SL)

plt.subplot(2,2,4)
plt.scatter(PW,SW)
plt.show()

# %%
lis = [PL,SL,PW,SW]
name = ["Petal Length", "Sepal Length", "Petal Width", "Sepal Width"]
for i in range(4):
    print(f"The mean of {name[i]} is: ",np.round(np.mean(lis[i]),3))
    print(f"The standard deviation of {name[i]} is: ",np.round(np.std(lis[i]),3))
    print(f"The median of {name[i]} is: ",np.round(statistics.median(lis[i]),3))
    print(f"The mode of {name[i]} is: ",np.round(statistics.mode(lis[i]),3))
    print("\n")
# Out:
# The mean of Petal Length is:  3.758
# The standard deviation of Petal Length is:  1.759
# The median of Petal Length is:  4.35
# The mode of Petal Length is:  1.4
#
#
# The mean of Sepal Length is:  5.843
# The standard deviation of Sepal Length is:  0.825
# The median of Sepal Length is:  5.8
# The mode of Sepal Length is:  5.0
#
#
# The mean of Petal Width is:  1.199
# The standard deviation of Petal Width is:  0.76
# The median of Petal Width is:  1.3
# The mode of Petal Width is:  0.2
#
#
# The mean of Sepal Width is:  3.057
# The standard deviation of Sepal Width is:  0.434
# The median of Sepal Width is:  3.0
# The mode of Sepal Width is:  3.0
